# %%
import numpy as np
from numpy import array
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import math

from keras.callbacks import EarlyStopping
from keras.models import Sequential

from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import SimpleRNN
from keras.layers import Dropout
from sklearn.model_selection import train_test_split

import tensorflow.keras.backend as K

# %%
dataset = pd.read_csv("Datasets1/combined_report_Centar.csv")

# %%
dataset = dataset.drop(columns = ["ozone", "precipAccumulation", "precipIntensity", "precipProbability", "pressure", "visibility", "CO", "NO2", "O3", "PM25", "SO2", "CO2", "AQI"])

# %%
dataset_bez_stringovi = dataset.drop(columns = ["icon", "precipType", "summary"])

# %%
dataset_bez_stringovi
# Out:
#        apparentTemperature  cloudCover  dewPoint  humidity  temperature  \
# 0                    11.77        1.00      7.85      0.55        21.67
# 1                    17.37        1.00      7.85      0.48        24.67
# 2                    16.02        1.00      8.89      0.51        24.67
# 3                    13.46        1.00     10.52      0.58        23.05
# 4                     6.93        1.00      7.09      0.58        19.36
# ...                    ...         ...       ...       ...          ...
# 22690                39.42        0.00     26.34      0.51        43.46
# 22691                37.49        0.19     26.79      0.51        43.50
# 22692                36.95        0.19     26.94      0.52        43.42
# 22693                42.48        0.01     29.11      0.59        42.48
# 22694                44.21        0.09     29.21      0.55        44.21
#
#              time  uvIndex  windBearing  windGust  windSpeed      PM10
# 0      1420106400      0.0         30.0      8.69       8.69   20.6300
# 1      1420110000      0.0         30.0      6.14       6.14   19.4400
# 2      1420117200      0.0         30.0      7.85       7.85   22.5200
# 3      1420120800      0.0         30.0      8.69       8.69   24.3500
# 4      1420128000      0.0         29.0     11.92      11.92   31.1700
# ...           ...      ...          ...       ...        ...       ...
# 22690  1545908400      2.0         33.0     13.10       6.80  168.4090
# 22691  1545912000      1.0         30.0     14.51      11.28   59.2807
# 22692  1545915600      1.0         28.0     12.60      12.60   59.2807
# 22693  1545998400      1.0        122.0      5.51       0.00  153.1630
# 22694  1546002000      1.0        139.0      4.62       0.00  208.1930
#
# [22695 rows x 11 columns]

# %%
train_dataset = dataset_bez_stringovi[:-2000]

# %%
train_dataset
# Out:
#        apparentTemperature  cloudCover  dewPoint  humidity  temperature  \
# 0                    11.77        1.00      7.85      0.55        21.67
# 1                    17.37        1.00      7.85      0.48        24.67
# 2                    16.02        1.00      8.89      0.51        24.67
# 3                    13.46        1.00     10.52      0.58        23.05
# 4                     6.93        1.00      7.09      0.58        19.36
# ...                    ...         ...       ...       ...          ...
# 20690                73.20        0.44     59.00      0.61        73.20
# 20691                71.42        1.00     59.00      0.65        71.42
# 20692                73.20        1.00     59.00      0.61        73.20
# 20693                71.52        1.00     60.80      0.69        71.42
# 20694                69.74        0.75     60.80      0.74        69.62
#
#              time  uvIndex  windBearing  windGust  windSpeed     PM10
# 0      1420106400      0.0         30.0      8.69       8.69  20.6300
# 1      1420110000      0.0         30.0      6.14       6.14  19.4400
# 2      1420117200      0.0         30.0      7.85       7.85  22.5200
# 3      1420120800      0.0         30.0      8.69       8.69  24.3500
# 4      1420128000      0.0         29.0     11.92      11.92  31.1700
# ...           ...      ...          ...       ...        ...      ...
# 20690  1534363200      0.0        290.0      0.00       6.93  38.9980
# 20691  1534366800      0.0        330.0      0.00       4.69  35.5917
# 20692  1534370400      0.0        320.0      0.00       4.69  30.5536
# 20693  1534374000      0.0        320.0      0.00       4.69  28.2480
# 20694  1534377600      0.0        311.0      0.00       2.24  24.7119
#
# [20695 rows x 11 columns]

# %%
test_dataset = dataset_bez_stringovi[-2000:]

# %%
test_dataset
# Out:
#        apparentTemperature  cloudCover  dewPoint  humidity  temperature  \
# 20695                69.96        0.75     62.59      0.78        69.62
# 20696                69.96        0.75     62.59      0.78        69.62
# 20697                68.21        0.75     62.59      0.83        67.81
# 20698                68.21        0.75     62.59      0.83        67.81
# 20699                71.73        0.75     62.59      0.74        71.42
# ...                    ...         ...       ...       ...          ...
# 22690                39.42        0.00     26.34      0.51        43.46
# 22691                37.49        0.19     26.79      0.51        43.50
# 22692                36.95        0.19     26.94      0.52        43.42
# 22693                42.48        0.01     29.11      0.59        42.48
# 22694                44.21        0.09     29.21      0.55        44.21
#
#              time  uvIndex  windBearing  windGust  windSpeed      PM10
# 20695  1534381200      0.0        311.0      0.00       2.24   23.3042
# 20696  1534384800      0.0        311.0      0.00       2.24   24.5864
# 20697  1534388400      0.0          0.0      0.00       0.00   25.7348
# 20698  1534392000      0.0        200.0      0.00       2.24   26.0143
# 20699  1534395600      0.0         41.0      0.00       6.93   26.2159
# ...           ...      ...          ...       ...        ...       ...
# 22690  1545908400      2.0         33.0     13.10       6.80  168.4090
# 22691  1545912000      1.0         30.0     14.51      11.28   59.2807
# 22692  1545915600      1.0         28.0     12.60      12.60   59.2807
# 22693  1545998400      1.0        122.0      5.51       0.00  153.1630
# 22694  1546002000      1.0        139.0      4.62       0.00  208.1930
#
# [2000 rows x 11 columns]

# %%
train_data = train_dataset.iloc[:,10].values
test_data = test_dataset.iloc[:,10].values

# %%
test_data
# Out:
# array([ 23.3042,  24.5864,  25.7348, ...,  59.2807, 153.163 , 208.193 ])

# %%
scaler = MinMaxScaler() #default od 0 do 1
train_data = np.reshape(train_data, (20695,1))
train_data = scaler.fit_transform(train_data)

# %%
test_data = np.reshape(test_data, (2000,1))
inputs = scaler.transform(test_data)

# %%
train_data = np.reshape(train_data, (20695, 1, 1))
inputs = np.reshape(inputs, (2000, 1, 1))

# %%
x_train = train_data[:-1]
y_train = train_data[1:]

# %%
regressor1 = Sequential()
regressor1.add(LSTM(50, return_sequences=True, input_shape = (None, 1)))
regressor1.add(Dropout(0.2))
regressor1.add(LSTM(50, return_sequences=True, input_shape = (None, 1)))
regressor1.add(Dropout(0.2))
regressor1.add(LSTM(50, return_sequences=True, input_shape = (None, 1)))
regressor1.add(Dropout(0.2))
regressor1.add(LSTM(50, return_sequences=True, input_shape = (None, 1)))
regressor1.add(Dropout(0.2))
regressor1.add(Dense(units = 1))

# %%
regressor1.compile(optimizer = 'adam', 
                  loss = 'mean_squared_error')

# %%
regressor1.fit(x_train, y_train, batch_size = 32, epochs = 50)
# Out:
# Epoch 1/50
# 647/647 [==============================] - 11s 6ms/step - loss: 0.0030
# Epoch 2/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0017
# Epoch 3/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 4/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 5/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0017
# Epoch 6/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0017
# Epoch 7/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0017
# Epoch 8/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 9/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 10/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0017
# Epoch 11/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 12/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 13/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 14/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 15/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 16/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0017
# Epoch 17/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 18/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 19/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 20/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0017
# Epoch 21/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 22/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 23/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0017
# Epoch 24/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 25/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 26/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 27/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 28/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 29/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 30/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 31/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 32/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 33/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 34/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 35/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 36/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 37/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 38/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 39/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 40/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 41/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 42/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 43/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 44/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 45/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 46/50
# 647/647 [==============================] - 4s 5ms/step - loss: 0.0016
# Epoch 47/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 48/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016
# Epoch 49/50
# 647/647 [==============================] - 4s 6ms/step - loss: 0.0016
# Epoch 50/50
# 647/647 [==============================] - 3s 5ms/step - loss: 0.0016

# %%
predicted = regressor1.predict(inputs)
predicted = predicted.reshape(2000,1)
predicted = scaler.inverse_transform(predicted)

# %%
rmse = math.sqrt(mean_squared_error(test_data, predicted))
print('Test Root Mean Squared Error:', rmse)
mae = mean_absolute_error(test_data, predicted)
print('Test Mean Absolute Error:', mae)
# Out:
# Test Root Mean Squared Error: 6.086651079982746
# Test Mean Absolute Error: 4.66917900743103

# %%
plt.figure()
plt.plot(test_data, color='red', label = 'Real PM10 amount')
plt.plot(predicted, color='blue', label = 'Predicted PM10 amount')
plt.title('PM10 Prediction')
plt.xlabel('Time')
plt.ylabel('PM10')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(np.abs(test_data - predicted), color='red', label = 'Mean Absolute Error')
plt.title('Mean Absolute Error')
plt.xlabel('Time')
plt.ylabel('PM10 absolut difference')
plt.legend()
plt.show()
